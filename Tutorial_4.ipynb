# %% [markdown]
# <a href="https://colab.research.google.com/github/ngyoozheng-2025/Data-Science-Tutorials/blob/main/Tutorial_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5f903f10-fdf3-412a-b725-58b910384570" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f903f10-fdf3-412a-b725-58b910384570">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !ls -lha ~/.kaggle
# Out:
# total 16K
# drwxr-xr-x 2 root root 4.0K Nov  5 14:49 .
# drwx------ 1 root root 4.0K Nov  5 14:49 ..
# -rw------- 1 root root   63 Nov  5 14:48 kaggle.json

# %% [markdown]
# #Q1

# %%
# !pip install kagglehub[pandas-datasets]

import kagglehub
from kagglehub import KaggleDatasetAdapter
import os

# Download dataset
path = kagglehub.dataset_download("kutayahin/goodreads-books-dataset")
print("Dataset path:", path)
print("Files:", os.listdir(path))

# ✅ Use the correct filename from the list
file_path = "goodreads_books_dataset.csv"

# New API version notice: prefer dataset_load()
df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "kutayahin/goodreads-books-dataset",
    file_path,
)

print("First 5 records:")
print(df.head())
# Out:
# ...
# Dataset path: /root/.cache/kagglehub/datasets/kutayahin/goodreads-books-dataset/versions/1
# Files: ['goodreads_books_dataset_README.md', 'goodreads_books_dataset.csv']
# First 5 records:
#    rank  percentile_rank   book_id  \
# 0     1              0.0  56859736
# 1     2              0.1  41212190
# 2     3              0.1  38479831
# 3     4              0.1  29380718
# 4     5              0.2  35514861
#
#                                                title             author  \
# 0                               Metaphysics of Sound    Nataša Pantović
# 1  Learn Spanish with stories and audios as workb...        Anton Hager
# 2                          Rivers Never Fill The Sea  Giselle V. Steele
# 3  Secret of the Cassin's Family Curse (Castle of...  Julie-Anne Gamble
# 4  What Healing Should Be: How to relieve pain an...  George  Alexandru
#
#    rating rating_category rating_tier  is_high_rated  title_length  \
# ...

# %% [markdown]
# #Q2

# %%
'''It's a good data, it contains of 3045 popular books which is plenty'''

# %% [markdown]
# #Q3

# %%
'''it has about 17 features
rating, rank, title has subtitle or not, author name, number of author ...
which I consider is enough'''

# %% [markdown]
# #Q4

# %%
'''i only shows 5 but it has 3000+ samples in fact, it is enough'''

# %% [markdown]
# #Q5

# %%
'''int, float, boolean, string'''

# %% [markdown]
# #Q6

# %%
df.isnull().sum()
# Out:
# rank                       0
# percentile_rank            0
# book_id                    0
# title                      0
# author                     0
# rating                     0
# rating_category            2
# rating_tier                0
# is_high_rated              0
# title_length               0
# title_complexity           0
# word_count                 0
# author_count               0
# author_name_length         0
# has_series_info            0
# series_number           1851
# title_type                 0
# has_subtitle               0
# has_middle_name            0
# estimated_popularity       0
# dtype: int64

# %%
'''in total it has many null values in series number and 2 in rating category. in the 5 outputs i displayed, the null values shows at series number, row 0,1,2 and 4.'''

# %% [markdown]
# #Q7

# %%
'''the target output is most probably the rating, rating category and rating tier since that's the most influential factor of a book, other columns are more likely features.'''

# %% [markdown]
# #Q8

# %%
'''if null values are considered as missing values, then in the 5 outputs i displayed, the missing values shows at series number, row 0,1,2 and 4.'''

# %% [markdown]
# #Q9

# %%
'''
a. which author has the highest rating or best books?
b. does series affect the rating of the books?
c. does the number of author affects the quality of the books?
d. does higher rating books normally has higher popularity?
'''
